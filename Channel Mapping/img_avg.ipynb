# %% [markdown]
# # Averaging Function Testing
# ## Imorting relevant directories

# %%
from pathlib import Path
import sys
sys.path.append('../')
from pma_open import *

# %% [markdown]
# ## Naming relevant paths

# %%
file_path_1 = '../Dropbox Files/hel1.pma'

# %% [markdown]
# ## Average Frame Array function (avg_frame_arr)

# %%
#Testing avg_frame_arr function
avg_frame_data = avg_frame_arr(file_path_1)
# Out:
# Image Size: 512 x 512
# Sucessfully generated average frame

# %%
print(f"Average Frame Data- shape: {avg_frame_data.shape}")
print(f"Average Frame Data- Type: {type(avg_frame_data)}")
print(f"Average Frame Data- dType: {avg_frame_data.dtype}")
# print(f"First line of Average Frame Data: {avg_frame_data[0]}")
# Out:
# Average Frame Data- shape: (512, 512)
# Average Frame Data- Type: <class 'numpy.ndarray'>
# Average Frame Data- dType: uint8

# %%
plt.imshow(avg_frame_data)

# %% [markdown]
# ## Average Frame png function (avg_frame_png)

# %%
#Testing avg_frame_png function
avg_frame_png(file_path_1)
# Out:
# Image Size: 512 x 512
# Image Size: 512 x 512
# Sucessfully generated average frame
# Average frame saved as: hel1_Avg_Frame.png

# %%
image_path_1 = "hel1_Avg_Frame/hel1_Avg_Frame.png"
hel1_avg_image = io.imread(image_path_1)

# show the image
print(type(hel1_avg_image))
print(hel1_avg_image.dtype)
print(hel1_avg_image.shape)
print(hel1_avg_image.min(), hel1_avg_image.max())

plt.imshow(hel1_avg_image, cmap="grey")
# Out:
# <class 'numpy.ndarray'>
# uint8
# (512, 512)
# 7 213

# %%
#Ensure hel2_Avg_Frame.png and hel12_Avg_Frame.png are also (512, 512, 3)
file_path_2 = '../Dropbox Files/hel2.pma'
file_path_12 = '../Dropbox Files/hel12.pma'

avg_frame_png(file_path_2)
avg_frame_png(file_path_12)

image_path_2 = "hel2_Avg_Frame/hel2_Avg_Frame.png"
image_path_12 = "hel12_Avg_Frame/hel12_Avg_Frame.png"

hel2_avg_image = io.imread(image_path_2)
hel12_avg_image = io.imread(image_path_12)
# Out:
# Image Size: 512 x 512
# Image Size: 512 x 512
# Sucessfully generated average frame
# Average frame saved as: hel2_Avg_Frame.png
# Image Size: 512 x 512
# Image Size: 512 x 512
# Sucessfully generated average frame
# Average frame saved as: hel12_Avg_Frame.png

# %%
# show the image
print(f"Shape of hel2_avg_image: {hel2_avg_image.shape}")
print(f"Shape of hel12_avg_image: {hel12_avg_image.shape}")
print(avg_frame_arr(file_path_1).shape)
# Out:
# Shape of hel2_avg_image: (512, 512)
# Shape of hel12_avg_image: (512, 512)
# Image Size: 512 x 512
# Sucessfully generated average frame
# (512, 512)
